# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %%
df = pd.read_csv('fb.csv')

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
corr = df.corr()
plt.figure(figsize = (10,10))

ax = sns.heatmap(
    corr,
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=80,
    horizontalalignment='right'
);

ax.set_yticklabels(
    ax.get_yticklabels(),
    horizontalalignment='right'
);

# %%
plt.figure(figsize=(10, 6))
children5 = df['Total Interactions'].value_counts()
sns.scatterplot(x = "Post Hour", y = "share", hue=children5, data = df)
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %%
plt.figure(figsize=(10, 6))
children5 = df['Type']
sns.scatterplot(x = "Post Hour", y = "share", hue=children5, data = df)
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %%
plt.figure(figsize=(10, 6))
children5 = df['Type']
sns.scatterplot(x = "Post Hour", y = "like", hue=children5, data = df)
plt.title('')

plt.figure(figsize=(10, 6))
sns.scatterplot(x = "Post Month", y = "like", hue=children5, data = df)
# Out:
# <AxesSubplot:xlabel='Post Month', ylabel='like'>

# %%
plt.figure(figsize=(10, 6))
children5 = df['Paid']
sns.scatterplot(x = "Type", y = "Total Interactions", hue=children5, data = df)
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %%
plt.figure(figsize=(10, 6))
children5 = df['Page total likes']
sns.scatterplot(x = "share", y = "like", hue=children5, data = df)
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %%
plt.figure(figsize=(10, 6))
children5 = df['Total Interactions']
sns.scatterplot(x = "Post Hour", y = "share", hue=children5, data = df)
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %%
plt.figure(figsize=(10, 6))
# Lifetime Post Consumers
children5 = df['Lifetime Post Consumers']
sns.scatterplot(x = "Post Hour", y = "like", hue=children5, data = df)
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %%
sns.pairplot(df, x_vars=['Post Month'], 
             y_vars='Page total likes', height=4, aspect=1, kind='scatter')
plt.show()

# %%
sns.pairplot(df, x_vars=['Post Weekday'], 
             y_vars='Total Interactions', height=4, aspect=1, kind='scatter')
plt.show()

# %%
sns.pairplot(df, x_vars=['Post Hour'], 
             y_vars='Total Interactions', height=4, aspect=1, kind='scatter')
plt.show()

# %%
sns.pairplot(df, x_vars=['Lifetime People who have liked your Page and engag]ed with your post', 'Total Interactions','Page total likes', 'Paid'], 
             y_vars='Lifetime Post Consumers', height=4, aspect=1, kind='scatter')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-3315df08d203> in <module>
# ----> 1 sns.pairplot(df, x_vars=['Lifetime People who have liked your Page and engag]ed with your post', 'Total Interactions','Page total likes', 'Paid'],
#       2              y_vars='Lifetime Post Consumers', height=4, aspect=1, kind='scatter')
#       3 plt.show()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
# ...

# %%
X = df['Total Interactions']
X2 = df['Page total likes']

y = df['Post Month']
y2 = df['Post Weekday']
y3 = df['Post Hour']
y4 = df['Lifetime Post Consumers']
y5 = df['Lifetime Post Total Reach']
# y6 = df['JobLevel']

# Splitting the varaibles as training and testing
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, 
                                                    test_size = 0.3, random_state = 100)

X_train, X_test, y2_train, y2_test = train_test_split(X, y2, train_size = 0.7, 
                                                    test_size = 0.3, random_state = 100)

X_train, X_test, y3_train, y3_test = train_test_split(X, y3, train_size = 0.7, 
                                                    test_size = 0.3, random_state = 100)

X_train, X_test, y4_train, y4_test = train_test_split(X, y4, train_size = 0.7, 
                                                    test_size = 0.3, random_state = 100)

X_train, X_test, y5_train, y5_test = train_test_split(X, y5, train_size = 0.7, 
                                                    test_size = 0.3, random_state = 100)

# X_train, X_test, y6_train, y6_test = train_test_split(X, y6, train_size = 0.7, 
#                                                     test_size = 0.3, random_state = 100)

X2_train, X2_test, y_train, y_test = train_test_split(X2, y, train_size = 0.7, 
                                                    test_size = 0.3, random_state = 100)



# Adding a constant to get an intercept
X_train_sm = sm.add_constant(X_train)
X2_train_sm = sm.add_constant(X2_train)



# Fitting the resgression line using 'OLS'
lr = sm.OLS(y_train, X_train_sm).fit()
lr2 = sm.OLS(y2_train, X_train_sm).fit()
lr3 = sm.OLS(y3_train, X_train_sm).fit()
lr4 = sm.OLS(y4_train, X_train_sm).fit()
lr5 = sm.OLS(y5_train, X_train_sm).fit()
# lr6 = sm.OLS(y6_train, X_train_sm).fit()

lr6 = sm.OLS(y_train, X2_train_sm).fit()

# Printing the parameters
lr.params

# %%
lr.summary()

# %%
plt.title("Total Interactions wise Post Hour")
plt.ylabel('Post Hour')
plt.xlabel("Total Interactions")


plt.scatter(X_train, y_train)
plt.plot(X_train, 6.9921 + 0.0003*X_train, 'r')
plt.show()

# %%
lr2.summary()

# %%
plt.title("Total Interactions wise Post Weekday")
plt.ylabel('Post Weekday')
plt.xlabel("Total Interactions")


plt.scatter(X_train, y2_train)
plt.plot(X_train, 4.2840 + -0.0003*X_train, 'r')
plt.show()

# %%
lr3.summary()

# %%
plt.title("Total Interactions wise Post Hour")
plt.ylabel('Post Hour')
plt.xlabel("Total Interactions")


plt.scatter(X_train, y3_train)
plt.plot(X_train, 8.0369 + -0.0007*X_train, 'r')
plt.show()

# %%
lr4.summary()

# %%
plt.title("Total Interactions wise Lifetime Post Consumers")
plt.ylabel('Lifetime Post Consumers')
plt.xlabel("Total Interactions")


plt.scatter(X_train, y4_train)
plt.plot(X_train, 629.5573 + 0.7101*X_train, 'r')
plt.show()

# %%
lr5.summary()

# %%
plt.title("Total Interactions wise Lifetime Post Total Reach")
plt.ylabel('Lifetime Post Total Reach')
plt.xlabel("Total Interactions")


plt.scatter(X_train, y5_train)
plt.plot(X_train, 7144.2986 + 31.0745*X_train, 'r')
plt.show()

# %%
sns.pairplot(df, x_vars=['Page total likes', 'Total Interactions'], 
             y_vars=['Post Hour', 'Post Weekday', 'Post Month'], height=4, aspect=1, kind='scatter')
plt.show()

# %%
lr6.summary()

# %%
plt.title("Page total likes wise Post Month")
plt.ylabel('Post Month')
plt.xlabel("Page total likes")


plt.scatter(X2_train, y_train)
plt.plot(X2_train, -16.5780 + 0.0002*X2_train, 'r')
plt.show()
